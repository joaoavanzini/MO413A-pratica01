# %% [markdown]
# # Practice 01 - MO413A
# # João Victor Palhares Barbosa

# %% [markdown]
# Import a CSV file

# %%
import pandas as pd
import seaborn as sn
# Out:
# /Users/palhares/opt/anaconda3/envs/msc/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('ebmocsna.csv')
df
# Out:
#     x1  x2  x3  x4     y1    y2     y3     y4
# 0   10  10  10   8   8.04  9.14   7.46   6.58
# 1    8   8   8   8   6.95  8.14   6.77   5.76
# 2   13  13  13   8   7.58  8.74  12.74   7.71
# 3    9   9   9   8   8.81  8.77   7.11   8.84
# 4   11  11  11   8   8.33  9.26   7.81   8.47
# 5   14  14  14   8   9.96  8.10   8.84   7.04
# 6    6   6   6   8   7.24  6.13   6.08   5.25
# 7    4   4   4  19   4.26  3.10   5.39  12.50
# 8   12  12  12   8  10.84  9.13   8.15   5.56
# 9    7   7   7   8   4.82  7.26   6.42   7.91
# 10   5   5   5   8   5.68  4.74   5.73   6.89

# %% [markdown]
# Average of the columns

# %%
df.x1.sum() / len(df.x1)
# Out:
# 9.0

# %%
df.x2.sum() / len(df.x2)
# Out:
# 9.0

# %%
df.x3.sum() / len(df.x3)
# Out:
# 9.0

# %%
df.x4.sum() / len(df.x4)
# Out:
# 9.0

# %%
df.y1.sum() / len(df.y1)
# Out:
# 7.500909090909093

# %%
df.y2.sum() / len(df.y2)
# Out:
# 7.50090909090909

# %%
df.y3.sum() / len(df.y3)
# Out:
# 7.5

# %%
df.y4.sum() / len(df.y4)
# Out:
# 7.500909090909091

# %% [markdown]
# Correlation matrix

# %%
correlation = df.corr()

# %%
sn.heatmap(correlation, annot=True, fmt=".3f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Graphics analysis

# %%
sn.boxplot(data=df, dodge=False)
# Out:
# <AxesSubplot:>
